# %% [markdown]
# ## Nomer 1
# ### Nama: Muflihun Abdul Firmansyah
# ### NIM: 190411100019

# %%
def sorting(tipe,ger,data):
    print("Nilai Awal: ", data)
    a = 0
    for i in range(len(data)-1,0,-1):
        print("Iterasi Ke-", len(data)-i, "Jumlah Iterasi-",i)
        if ger == '1':
                if tipe == 'asc':
                    for j in range(i):
                        if data[j] > data[j+1]:
                            data[j],data[j+1] = data[j+1],data[j]
                        print(j+1,'=' ,data)
                else:
                    a = 0
                    for j in range(len(data)-1,len(data)-i-1,-1):
                        a += 1
                        if data[j-1] < data[j]:
                            data[j-1],data[j] = data[j],data[j-1]
                        print(a, '=',data)
                    
        else:
            a = 0
            if tipe == 'asc':
                for j in range(len(data)-1,len(data)-i-1,-1):
                    a += 1
                    if data[j] < data[j-1]:
                        data[j],data[j-1] = data[j-1],data[j]
                    print(a,'=',data)
                    
            else:
                for j in range(i):
                    if data[j] < data[j+1]:
                        data[j],data[j+1] = data[j+1],data[j]
                    print(j+1,'=',data)
    
a = [10,2,1,13,15,22,11,45]
sorting('desc','1',a)

# %% [markdown]
# ## Nomer 2

# %%
def modifsort(tipe,ger,data):
    print("Nilai Awal: ", data)
    a = 0
    for i in range(len(data)-1,0,-1):
        print("Iterasi Ke-", len(data)-i, "Jumlah Iterasi-",i)
        if ger == '1':
                if tipe == 'asc':
                    for j in range(i):
                        if data[j] > data[j+1]:
                            data[j],data[j+1] = data[j+1],data[j]
                        print(j+1,'=' ,data)
                else:
                    a = 0
                    for j in range(len(data)-1,len(data)-i-1,-1):
                        a += 1
                        if data[j-1] < data[j]:
                            data[j-1],data[j] = data[j],data[j-1]
                        print(a, '=',data)         
        else:
            
            if tipe == 'asc':
                a = 0
                for j in range(len(data)-1,len(data)-i-1,-1):
                    a += 1
                    if data[j] < data[j-1]:
                        data[j],data[j-1] = data[j-1],data[j]
                    print(a,'=',data)
                    
            else:
                for j in range(i):
                    if data[j] < data[j+1]:
                        data[j],data[j+1] = data[j+1],data[j]
                    print(j+1,'=',data)
        cek = True
        for k in range(len(data)-1):
            if tipe == 'asc':
                if data[k] <= data[k+1]:
                    cek = cek and True
                else:
                    cek = cek and False
            else:
                if data[k] >= data[k+1]:
                    cek = cek and True
                else:
                    cek = cek and False
        if cek:
            print("Data Sudah Urut: ", data)
            return data
a = [10,2,1,13,15,22,11,45]
modifsort('desc','1',a)

# %% [markdown]
# ## Nomer 3

# %%
import time
def sorting(tipe,ger,data):
    awal = time.time()
    print("Nilai Awal: ", data)
    a = 0
    for i in range(len(data)-1,0,-1):
        if ger == '1':
                if tipe == 'asc':
                    for j in range(i):
                        if data[j] > data[j+1]:
                            data[j],data[j+1] = data[j+1],data[j]
                        
                else:
                    for j in range(len(data)-1,len(data)-i-1,-1):
                        if data[j-1] < data[j]:
                            data[j-1],data[j] = data[j],data[j-1]
                    
        else:
            if tipe == 'asc':
                for j in range(len(data)-1,len(data)-i-1,-1):
                    if data[j] < data[j-1]:
                        data[j],data[j-1] = data[j-1],data[j]
            else:
                for j in range(i):
                    if data[j] < data[j+1]:
                        data[j],data[j+1] = data[j+1],data[j]
    akhir = time.time()
    hasil = akhir-awal
    print('waktu: ', hasil)
    print('data sudah diurutkan: ', data)

# %%
def modifsort(tipe,ger,data):
    awal = time.time()
    print("Nilai Awal: ", data)
    a = 0
    for i in range(len(data)-1,0,-1):
        if ger == '1':
                if tipe == 'asc':
                    for j in range(i):
                        if data[j] > data[j+1]:
                            data[j],data[j+1] = data[j+1],data[j]
                else:
                    for j in range(len(data)-1,len(data)-i-1,-1):
                        if data[j-1] < data[j]:
                            data[j-1],data[j] = data[j],data[j-1]
        else:
            if tipe == 'asc':
                for j in range(len(data)-1,len(data)-i-1,-1):
                    if data[j] < data[j-1]:
                        data[j],data[j-1] = data[j-1],data[j]
            else:
                for j in range(i):
                    if data[j] < data[j+1]:
                        data[j],data[j+1] = data[j+1],data[j]
        cek = True
        for k in range(len(data)-1):
            if tipe == 'asc':
                if data[k] <= data[k+1]:
                    cek = cek and True
                else:
                    cek = cek and False
            else:
                if data[k] >= data[k+1]:
                    cek = cek and True
                else:
                    cek = cek and False
        if cek:
            print("Data Sudah Urut: ", data)
            akhir = time.time()
            hasil = akhir-awal
            return 'Waktu: ',hasil, 'Data: ',data

# %%
import random
a = random.sample(range(0,100),50)
modifsort('asc','1',a)
# Out:
# Nilai Awal:  [40, 61, 65, 58, 64, 86, 59, 22, 39, 83, 28, 46, 82, 2, 74, 9, 38, 19, 42, 3, 35, 52, 11, 55, 69, 1, 13, 37, 97, 75, 87, 23, 24, 90, 99, 45, 17, 41, 6, 29, 26, 80, 10, 53, 94, 8, 50, 21, 62, 20]
# Data Sudah Urut:  [1, 2, 3, 6, 8, 9, 10, 11, 13, 17, 19, 20, 21, 22, 23, 24, 26, 28, 29, 35, 37, 38, 39, 40, 41, 42, 45, 46, 50, 52, 53, 55, 58, 59, 61, 62, 64, 65, 69, 74, 75, 80, 82, 83, 86, 87, 90, 94, 97, 99]
# ('Waktu: ',
#  0.0036389827728271484,
#  'Data: ',
#  [1,
#   2,
#   3,
#   6,
#   8,
#   9,
#   10,
#   11,
#   13,
#   17,
#   19,
#   20,
#   21,
#   22,
#   23,
#   24,
#   26,
#   28,
#   29,
#   35,
#   37,
#   38,
#   39,
#   40,
#   41,
#   42,
#   45,
#   46,
#   50,
#   52,
#   53,
#   55,
#   58,
#   59,
#   61,
#   62,
#   64,
#   65,
#   69,
#   74,
#   75,
#   80,
#   82,
#   83,
#   86,
#   87,
#   90,
#   94,
#   97,
#   99])
